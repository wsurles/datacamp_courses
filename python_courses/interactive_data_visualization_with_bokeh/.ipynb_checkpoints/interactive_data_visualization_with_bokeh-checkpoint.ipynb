# %% [markdown]
# # Interavtive Data Visualization with Bokeh
# - William Surles
# - 2017-11-14
# - Datacamp class
# - [https://www.datacamp.com/courses/interactive-data-visualization-with-bokeh](https://www.datacamp.com/courses/interactive-data-visualization-with-bokeh)

# %% [markdown]
# ## Whats Covered

# %% [markdown]
# - Basic Plotting with Bokeh
#  - Plotting with glyphs
#  - Additional glyphs
#  - Data formats
#  - Customizing glyphs
# - Layouts, Interactions, and Annotations
#  - Introduction to layouts
#  - Advanced layouts
#  - Linking plots together
#  - Annotations and guides
# - Building interactive apps with Bokeh
#  - Introducing the Bokeh Server
#  - Connecting sliders to plots
#  - Updating plots from dropdowns
#  - Buttons
#  - Hosting applications for wider audiences
# - Putting it all together! A case study
#  - Time to put it all together!
#  - Starting the app
#  - Adding more interactivity to the app
#  - Congratulations!

# %% [markdown]
# ## Additonal Resources

# %% [markdown]
# ## Libraries and Data

# %% [markdown]
# # Basic Plotting with Bokeh

# %% [markdown]
# ## Plotting with glyphs

# %% [markdown]
# #### What are Glyphs
# - Visual shapes
#  - circles, squares, triangles
#  - rectangles, lines, wedges
# - With properties attached to data
#  - coordinates (x,y)
#  - size, color, transparency

# %% [markdown]
# #### Typical usage
#  - Its common to use output_file to print out these charts as html files tobe viewed in a browser
#  - or to use output_notebook to put them inline in a notebook

# %%
import numpy as np
from bokeh.io import output_file, output_notebook
from bokeh.plotting import figure, show

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f6807b4e-95c1-4d85-8f39-c74961d3c727">Loading BokehJS ...</span>
#     </div>

# %%
plot = figure(plot_width=400, tools = 'pan, box_zoom')
plot.circle([1,2,3,4,5], [8,6,5,2,3])
show(plot, notebook_handle=True, browser_handle=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-4c12abfc4a5d> in <module>()
#       1 plot = figure(plot_width=400, tools = 'pan, box_zoom')
#       2 plot.circle([1,2,3,4,5], [8,6,5,2,3])
# ----> 3 show(plot, notebook_handle=True, browser_handle=False)
#
# ~/anaconda3/envs/python_datacamp/lib/python3.6/site-packages/bokeh/util/api.py in wrapper(*args, **kw)
#     188         @wraps(obj)
#     189         def wrapper(*args, **kw):
# --> 190             return obj(*args, **kw)
#     191
#     192         wrapper.__bkversion__ = version
#
# TypeError: show() got an unexpected keyword argument 'browser_handle'

# %% [markdown]
# ### What are glyphs?

# %% [markdown]
# ### A simple scatter plot

# %% [markdown]
# ### A scatter plot with different shapes

# %% [markdown]
# ### Customizing your scatter plots

# %% [markdown]
# ## Additional glyphs

# %% [markdown]
# ### Lines

# %% [markdown]
# ### Lines and markers

# %% [markdown]
# ### Patches

# %% [markdown]
# ## Data formats

# %% [markdown]
# ### Plotting data from NumPy arrays

# %% [markdown]
# ### Plotting data from Pandas DataFrames

# %% [markdown]
# ### The Bokeh ColumnDataSource

# %% [markdown]
# ### The Bokeh ColumnDataSource (continued)

# %% [markdown]
# ## Customizing glyphs

# %% [markdown]
# ### Selection and non-selection glyphs

# %% [markdown]
# ### Hover glyphs

# %% [markdown]
# ### Colormapping

# %% [markdown]
# # Layouts, Interactions, and Annotations

# %% [markdown]
# ## Introduction to layouts

# %% [markdown]
# ### Creating rows of plots

# %% [markdown]
# ### Creating columns of plots

# %% [markdown]
# ### Nesting rows and columns of plots

# %% [markdown]
# ## Advanced layouts

# %% [markdown]
# ### Investigating the layout API

# %% [markdown]
# ### Creating gridded layouts

# %% [markdown]
# ### Starting tabbed layouts

# %% [markdown]
# ### Displaying tabbed layouts

# %% [markdown]
# ## Linking plots together

# %% [markdown]
# ### Linked axes

# %% [markdown]
# ### Linked brushing

# %% [markdown]
# ## Annotations and guides

# %% [markdown]
# ### How to create legends

# %% [markdown]
# ### Positioning and styling legends

# %% [markdown]
# ### Hover tooltips for exposing details

# %% [markdown]
# ### Adding a hover tooltip

# %% [markdown]
# # Building interactive apps with Bokeh

# %% [markdown]
# ## Introducing the Bokeh Server

# %% [markdown]
# ### Understanding Bokeh apps

# %% [markdown]
# ### Using the current document

# %% [markdown]
# ### Add a single slider

# %% [markdown]
# ### Multiple sliders in one document

# %% [markdown]
# ## Connecting sliders to plots

# %% [markdown]
# ### Adding callbacks to sliders

# %% [markdown]
# ### How to combine Bokeh models into layouts

# %% [markdown]
# ### Learn about widget callbacks

# %% [markdown]
# ## Updating plots from dropdowns

# %% [markdown]
# ### Updating data sources from dropdown callbacks

# %% [markdown]
# ### Synchronize two dropdowns

# %% [markdown]
# ## Buttons

# %% [markdown]
# ### Button widgets

# %% [markdown]
# ### Button styles

# %% [markdown]
# ## Hosting applications for wider audiences

# %% [markdown]
# # Putting It All Together! A Case Study

# %% [markdown]
# ## Time to put it all together!

# %% [markdown]
# ### Introducing the project dataset

# %% [markdown]
# ### Some exploratory plots of the data

# %% [markdown]
# ## Starting the app

# %% [markdown]
# ### Beginning with just a plot

# %% [markdown]
# ### Enhancing the plot with some shading

# %% [markdown]
# ### Adding a slider to vary the year

# %% [markdown]
# ### Customizing based on user input

# %% [markdown]
# ## Adding more interactivity to the app

# %% [markdown]
# ### Adding a hover tool

# %% [markdown]
# ### Adding dropdowns to the app

# %% [markdown]
# ## Congratulations!
